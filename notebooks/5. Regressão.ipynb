# %% [markdown]
# # Modelos de Regressão
#
# Este notebook investiga diferentes abordagens de regressão para análise de dados, com foco nos modelos de Regressão Linear e Lasso. São aplicadas técnicas de pré-processamento, como a transformação de Box-Cox, visando aprimorar a modelagem. A avaliação dos modelos é feita com base em métricas como RMSE e R², considerando tanto o conjunto completo de dados quanto versões filtradas após a remoção de outliers das questões do Enem (vetorizadas).

# %% [markdown]
# ## Apoio

# %%
# Importando Dependências para Modelos de Regressão
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats
import statsmodels.api as sm

from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error
from sklearn.linear_model import LassoCV, Lasso
from sklearn.model_selection import train_test_split

# %%
# Leitura do dataset
df_enem = pd.read_pickle('../data/final/enem_data_embeddings.pkl')
df_enem.head()
# Out:
#    numero_questao gabarito  NU_PARAM_A  nu_param_B  NU_PARAM_C   ANO  \
# 0               1        C     3.43894     0.97831     0.10855  2017
# 1               2        D     3.00837     0.49169     0.13877  2017
# 2               3        D     0.60432     3.25992     0.08798  2017
# 3               4        E     1.85031     0.57925     0.11344  2017
# 4               5        C     2.46290     0.76307     0.17672  2017
#
#                                            enunciado  \
# 0  No império africano do Mali, no século XIV, To...
# 1  Após a Declaração Universal dos Direitos Human...
# 2  A moralidade, Bentham exortava, não é uma ques...
# 3  Fala-se muito nos dias de hoje em direitos do ...
# 4  Na Constituição da República Federativa do Bra...
#
#                                         alternativas  \
# 0  A:  isolamento geográﬁco do Saara ocidental; B...
# 1  A:  ataque feito pelos japoneses à base milita...
# 2  A:  fundamentação cientíﬁca de viés positivist...
# 3  A: modernização da educação escolar; B: atuali...
# 4  A:  etnia e miscigenação racial; B:  sociedade...
#
#                                  alternativa_correta  \
# 0           posição relativa nas redes de circulação
# 1  execução de judeus e eslavos presos em guetos ...
# 2                racionalidade de caráter pragmático
# 3    universalização do princípio da igualdade civil
# 4                    espaço e sobrevivência cultural
#
#                        enunciado_embbedings_word2vec  \
# 0  [-0.030405086, 0.022974016, -0.027739665, -0.0...
# 1  [-0.03320758, 0.03166411, -0.04888896, 0.01524...
# 2  [-0.0063855667, 0.022534302, -0.014108029, -0....
# 3  [-0.014004647, 0.02424562, -0.010280999, 0.010...
# 4  [-0.013194435, 0.01645982, -0.0011703374, -0.0...
#
#                         gabarito_embbedings_word2vec
# 0  [-0.12797333, -0.114192665, 0.13532682, -0.057...
# 1  [-0.18022183, 0.041319773, -0.06070747, -0.069...
# 2  [-0.049211252, 0.073626995, 0.013877999, 0.085...
# 3  [-0.06145667, 0.129228, -0.004840499, 0.033785...
# 4  [0.045796998, -0.120854005, 0.06641175, -0.123...

# %%
# Removendo o ano de 2021
df_enem_aux = df_enem.drop(df_enem[df_enem['ANO'] == 2021].index).reset_index()
df_enem_aux = df_enem_aux[df_enem_aux['nu_param_B'].notna()]

# %% [markdown]
# ## Regressão Linear

# %% [markdown]
# ### Dataset Completo

# %%
# Separando os dados
X = [np.array(embedding) for embedding in df_enem_aux['enunciado_embbedings_word2vec']]
y = df_enem_aux['nu_param_B']

# %%
# Aplicando Transformações
add_list = [(y.min() * (-1)) + 1] * len(y)
y = y + add_list

# Aplicando Boxcox
y, _ = stats.boxcox(y)

# %%
# Separando em conjunto de treino e teste
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
# Adicionando constante
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %%
model = sm.OLS(y_train, X_train).fit()
print(model.summary(alpha=0.05))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 12 May 2025   Prob (F-statistic):                nan
# Time:                        18:55:42   Log-Likelihood:                 5924.3
# No. Observations:                 186   AIC:                        -1.148e+04
# Df Residuals:                       0   BIC:                        -1.088e+04
# Df Model:                         185
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.1110        inf          0        nan         nan         nan
# x1             1.1813        inf          0        nan         nan         nan
# x2            -2.5461        inf         -0        nan         nan         nan
# x3            -1.1082        inf         -0        nan         nan         nan
# x4             0.9379        inf          0        nan         nan         nan
# x5             1.8365        inf          0        nan         nan         nan
# x6            -3.9487        inf         -0        nan         nan         nan
# x7            -0.4963        inf         -0        nan         nan         nan
# x8            -0.8487        inf         -0        nan         nan         nan
# x9             1.6876        inf          0        nan         nan         nan
# x10            1.7070        inf          0        nan         nan         nan
# x11            0.2439        inf          0        nan         nan         nan
# x12           -1.8198        inf         -0        nan         nan         nan
# x13           -0.1831        inf         -0        nan         nan         nan
# x14           -2.7278        inf         -0        nan         nan         nan
# x15            1.1366        inf          0        nan         nan         nan
# x16            0.1160        inf          0        nan         nan         nan
# x17            2.3459        inf          0        nan         nan         nan
# x18            4.0340        inf          0        nan         nan         nan
# x19            1.2969        inf          0        nan         nan         nan
# x20           -0.6501        inf         -0        nan         nan         nan
# x21           -0.7113        inf         -0        nan         nan         nan
# x22           -1.1235        inf         -0        nan         nan         nan
# x23           -0.0776        inf         -0        nan         nan         nan
# x24            2.6962        inf          0        nan         nan         nan
# x25            2.9527        inf          0        nan         nan         nan
# x26            1.8940        inf          0        nan         nan         nan
# x27           -1.3387        inf         -0        nan         nan         nan
# x28            1.7385        inf          0        nan         nan         nan
# x29           -0.3923        inf         -0        nan         nan         nan
# x30            3.1249        inf          0        nan         nan         nan
# x31            2.5753        inf          0        nan         nan         nan
# x32           -1.9240        inf         -0        nan         nan         nan
# x33           -1.3834        inf         -0        nan         nan         nan
# x34            1.3632        inf          0        nan         nan         nan
# x35           -0.2648        inf         -0        nan         nan         nan
# x36            4.9710        inf          0        nan         nan         nan
# x37            1.6378        inf          0        nan         nan         nan
# x38            1.0458        inf          0        nan         nan         nan
# x39            0.3489        inf          0        nan         nan         nan
# x40            3.1607        inf          0        nan         nan         nan
# x41           -1.9130        inf         -0        nan         nan         nan
# x42            0.0693        inf          0        nan         nan         nan
# x43            0.1001        inf          0        nan         nan         nan
# x44            0.0595        inf          0        nan         nan         nan
# x45            1.0984        inf          0        nan         nan         nan
# x46            0.7558        inf          0        nan         nan         nan
# x47            1.7826        inf          0        nan         nan         nan
# x48            0.3239        inf          0        nan         nan         nan
# x49           -1.6634        inf         -0        nan         nan         nan
# x50            3.7401        inf          0        nan         nan         nan
# x51           -0.1023        inf         -0        nan         nan         nan
# x52            0.2334        inf          0        nan         nan         nan
# x53           -0.8666        inf         -0        nan         nan         nan
# x54           -0.8737        inf         -0        nan         nan         nan
# x55            1.9197        inf          0        nan         nan         nan
# x56            1.2874        inf          0        nan         nan         nan
# x57            0.8829        inf          0        nan         nan         nan
# x58            0.8085        inf          0        nan         nan         nan
# x59            1.2263        inf          0        nan         nan         nan
# x60           -1.3158        inf         -0        nan         nan         nan
# x61            2.4168        inf          0        nan         nan         nan
# x62           -1.1639        inf         -0        nan         nan         nan
# x63            0.9589        inf          0        nan         nan         nan
# x64            1.8295        inf          0        nan         nan         nan
# x65           -2.6025        inf         -0        nan         nan         nan
# x66           -0.1257        inf         -0        nan         nan         nan
# x67           -2.4542        inf         -0        nan         nan         nan
# x68           -0.3921        inf         -0        nan         nan         nan
# x69            0.8109        inf          0        nan         nan         nan
# x70           -0.7088        inf         -0        nan         nan         nan
# x71            0.9874        inf          0        nan         nan         nan
# x72            1.1579        inf          0        nan         nan         nan
# x73           -2.7294        inf         -0        nan         nan         nan
# x74            3.5682        inf          0        nan         nan         nan
# x75           -1.2605        inf         -0        nan         nan         nan
# x76           -0.8219        inf         -0        nan         nan         nan
# x77           -0.1873        inf         -0        nan         nan         nan
# x78           -1.8934        inf         -0        nan         nan         nan
# x79           -1.4438        inf         -0        nan         nan         nan
# x80            2.5751        inf          0        nan         nan         nan
# x81           -0.9879        inf         -0        nan         nan         nan
# x82           -1.9365        inf         -0        nan         nan         nan
# x83            0.3168        inf          0        nan         nan         nan
# x84            0.0107        inf          0        nan         nan         nan
# x85            0.1876        inf          0        nan         nan         nan
# x86           -2.3104        inf         -0        nan         nan         nan
# x87            4.3979        inf          0        nan         nan         nan
# x88            4.9452        inf          0        nan         nan         nan
# x89            1.7895        inf          0        nan         nan         nan
# x90           -1.8265        inf         -0        nan         nan         nan
# x91            4.3346        inf          0        nan         nan         nan
# x92           -0.2282        inf         -0        nan         nan         nan
# x93            2.4834        inf          0        nan         nan         nan
# x94            2.2744        inf          0        nan         nan         nan
# x95           -2.0751        inf         -0        nan         nan         nan
# x96           -2.8092        inf         -0        nan         nan         nan
# x97           -0.8429        inf         -0        nan         nan         nan
# x98            0.6080        inf          0        nan         nan         nan
# x99           -0.6686        inf         -0        nan         nan         nan
# x100          -1.6609        inf         -0        nan         nan         nan
# x101          -2.3834        inf         -0        nan         nan         nan
# x102           0.2307        inf          0        nan         nan         nan
# x103          -0.8124        inf         -0        nan         nan         nan
# x104          -0.1014        inf         -0        nan         nan         nan
# x105          -3.2810        inf         -0        nan         nan         nan
# x106          -0.3867        inf         -0        nan         nan         nan
# x107          -1.4594        inf         -0        nan         nan         nan
# x108          -3.2520        inf         -0        nan         nan         nan
# x109          -0.5202        inf         -0        nan         nan         nan
# x110          -0.2486        inf         -0        nan         nan         nan
# x111          -1.1315        inf         -0        nan         nan         nan
# x112          -3.4092        inf         -0        nan         nan         nan
# x113           2.1485        inf          0        nan         nan         nan
# x114          -2.6001        inf         -0        nan         nan         nan
# x115           1.5487        inf          0        nan         nan         nan
# x116          -0.0297        inf         -0        nan         nan         nan
# x117          -0.0024        inf         -0        nan         nan         nan
# x118          -3.4247        inf         -0        nan         nan         nan
# x119           0.5895        inf          0        nan         nan         nan
# x120           1.4949        inf          0        nan         nan         nan
# x121          -0.3090        inf         -0        nan         nan         nan
# x122           2.1587        inf          0        nan         nan         nan
# x123          -0.7496        inf         -0        nan         nan         nan
# x124          -1.6785        inf         -0        nan         nan         nan
# x125          -0.6299        inf         -0        nan         nan         nan
# x126           0.1180        inf          0        nan         nan         nan
# x127          -0.5527        inf         -0        nan         nan         nan
# x128          -4.6354        inf         -0        nan         nan         nan
# x129          -1.8243        inf         -0        nan         nan         nan
# x130           3.2930        inf          0        nan         nan         nan
# x131           0.3936        inf          0        nan         nan         nan
# x132           3.2694        inf          0        nan         nan         nan
# x133          -1.5317        inf         -0        nan         nan         nan
# x134           0.4849        inf          0        nan         nan         nan
# x135           0.7478        inf          0        nan         nan         nan
# x136          -1.9032        inf         -0        nan         nan         nan
# x137          -1.0087        inf         -0        nan         nan         nan
# x138          -1.7180        inf         -0        nan         nan         nan
# x139           0.1689        inf          0        nan         nan         nan
# x140          -2.2348        inf         -0        nan         nan         nan
# x141           2.2402        inf          0        nan         nan         nan
# x142           0.2509        inf          0        nan         nan         nan
# x143          -1.7144        inf         -0        nan         nan         nan
# x144          -1.4249        inf         -0        nan         nan         nan
# x145          -2.1295        inf         -0        nan         nan         nan
# x146          -0.6386        inf         -0        nan         nan         nan
# x147           0.7803        inf          0        nan         nan         nan
# x148          -0.9203        inf         -0        nan         nan         nan
# x149          -2.1154        inf         -0        nan         nan         nan
# x150           0.7367        inf          0        nan         nan         nan
# x151           2.6713        inf          0        nan         nan         nan
# x152           2.7235        inf          0        nan         nan         nan
# x153          -2.9180        inf         -0        nan         nan         nan
# x154           0.0756        inf          0        nan         nan         nan
# x155           0.9849        inf          0        nan         nan         nan
# x156          -0.7888        inf         -0        nan         nan         nan
# x157          -1.1885        inf         -0        nan         nan         nan
# x158          -1.4196        inf         -0        nan         nan         nan
# x159          -3.3974        inf         -0        nan         nan         nan
# x160           0.4382        inf          0        nan         nan         nan
# x161          -0.1814        inf         -0        nan         nan         nan
# x162          -0.8009        inf         -0        nan         nan         nan
# x163           0.8886        inf          0        nan         nan         nan
# x164           2.3403        inf          0        nan         nan         nan
# x165          -2.1199        inf         -0        nan         nan         nan
# x166          -0.5644        inf         -0        nan         nan         nan
# x167          -1.7944        inf         -0        nan         nan         nan
# x168          -0.4720        inf         -0        nan         nan         nan
# x169          -0.8978        inf         -0        nan         nan         nan
# x170           0.5960        inf          0        nan         nan         nan
# x171           4.6463        inf          0        nan         nan         nan
# x172           1.1976        inf          0        nan         nan         nan
# x173           2.9596        inf          0        nan         nan         nan
# x174           0.8517        inf          0        nan         nan         nan
# x175           1.0670        inf          0        nan         nan         nan
# x176          -1.0436        inf         -0        nan         nan         nan
# x177          -2.4321        inf         -0        nan         nan         nan
# x178          -2.2429        inf         -0        nan         nan         nan
# x179           0.3032        inf          0        nan         nan         nan
# x180          -1.5558        inf         -0        nan         nan         nan
# x181          -0.6371        inf         -0        nan         nan         nan
# x182          -0.8593        inf         -0        nan         nan         nan
# x183          -0.3112        inf         -0        nan         nan         nan
# x184          -4.0056        inf         -0        nan         nan         nan
# x185           0.3369        inf          0        nan         nan         nan
# x186           2.6015        inf          0        nan         nan         nan
# x187           2.7059        inf          0        nan         nan         nan
# x188          -2.8112        inf         -0        nan         nan         nan
# x189          -3.3103        inf         -0        nan         nan         nan
# x190           0.6790        inf          0        nan         nan         nan
# x191           0.3893        inf          0        nan         nan         nan
# x192          -2.7011        inf         -0        nan         nan         nan
# x193          -1.8423        inf         -0        nan         nan         nan
# x194          -0.8495        inf         -0        nan         nan         nan
# x195           3.2562        inf          0        nan         nan         nan
# x196           3.2082        inf          0        nan         nan         nan
# x197          -1.0217        inf         -0        nan         nan         nan
# x198           1.0423        inf          0        nan         nan         nan
# x199           3.5984        inf          0        nan         nan         nan
# x200           0.3309        inf          0        nan         nan         nan
# x201          -0.4278        inf         -0        nan         nan         nan
# x202           0.8788        inf          0        nan         nan         nan
# x203          -1.1092        inf         -0        nan         nan         nan
# x204          -0.1917        inf         -0        nan         nan         nan
# x205           2.4265        inf          0        nan         nan         nan
# x206           0.6235        inf          0        nan         nan         nan
# x207          -0.2085        inf         -0        nan         nan         nan
# x208          -0.9755        inf         -0        nan         nan         nan
# x209          -2.1438        inf         -0        nan         nan         nan
# x210          -2.6290        inf         -0        nan         nan         nan
# x211           2.0686        inf          0        nan         nan         nan
# x212          -2.0283        inf         -0        nan         nan         nan
# x213           0.3182        inf          0        nan         nan         nan
# x214          -1.4563        inf         -0        nan         nan         nan
# x215           0.4549        inf          0        nan         nan         nan
# x216           2.0894        inf          0        nan         nan         nan
# x217           2.2313        inf          0        nan         nan         nan
# x218          -0.2770        inf         -0        nan         nan         nan
# x219          -2.4625        inf         -0        nan         nan         nan
# x220          -3.0372        inf         -0        nan         nan         nan
# x221          -0.3819        inf         -0        nan         nan         nan
# x222          -0.1838        inf         -0        nan         nan         nan
# x223          -0.2841        inf         -0        nan         nan         nan
# x224          -2.4597        inf         -0        nan         nan         nan
# x225           1.3789        inf          0        nan         nan         nan
# x226          -1.4801        inf         -0        nan         nan         nan
# x227           2.3352        inf          0        nan         nan         nan
# x228           0.6591        inf          0        nan         nan         nan
# x229          -0.2910        inf         -0        nan         nan         nan
# x230          -1.5868        inf         -0        nan         nan         nan
# x231           4.8694        inf          0        nan         nan         nan
# x232           1.1012        inf          0        nan         nan         nan
# x233          -1.6089        inf         -0        nan         nan         nan
# x234           3.2203        inf          0        nan         nan         nan
# x235           4.8365        inf          0        nan         nan         nan
# x236           0.2818        inf          0        nan         nan         nan
# x237           1.8942        inf          0        nan         nan         nan
# x238          -3.9741        inf         -0        nan         nan         nan
# x239           2.9157        inf          0        nan         nan         nan
# x240           1.4471        inf          0        nan         nan         nan
# x241          -1.8525        inf         -0        nan         nan         nan
# x242          -3.9828        inf         -0        nan         nan         nan
# x243          -0.9583        inf         -0        nan         nan         nan
# x244           0.4256        inf          0        nan         nan         nan
# x245           0.0239        inf          0        nan         nan         nan
# x246           2.4483        inf          0        nan         nan         nan
# x247           0.2680        inf          0        nan         nan         nan
# x248          -1.0119        inf         -0        nan         nan         nan
# x249           3.0524        inf          0        nan         nan         nan
# x250           2.9764        inf          0        nan         nan         nan
# x251          -1.0112        inf         -0        nan         nan         nan
# x252          -1.7345        inf         -0        nan         nan         nan
# x253          -1.3480        inf         -0        nan         nan         nan
# x254          -1.5805        inf         -0        nan         nan         nan
# x255           1.5237        inf          0        nan         nan         nan
# x256          -2.2324        inf         -0        nan         nan         nan
# x257           1.0786        inf          0        nan         nan         nan
# x258           2.2171        inf          0        nan         nan         nan
# x259          -0.6030        inf         -0        nan         nan         nan
# x260          -0.9195        inf         -0        nan         nan         nan
# x261           1.2463        inf          0        nan         nan         nan
# x262          -2.9048        inf         -0        nan         nan         nan
# x263          -0.1080        inf         -0        nan         nan         nan
# x264           0.4944        inf          0        nan         nan         nan
# x265           1.6947        inf          0        nan         nan         nan
# x266          -0.0432        inf         -0        nan         nan         nan
# x267           3.1881        inf          0        nan         nan         nan
# x268          -0.1175        inf         -0        nan         nan         nan
# x269           1.0270        inf          0        nan         nan         nan
# x270          -1.9003        inf         -0        nan         nan         nan
# x271          -0.7180        inf         -0        nan         nan         nan
# x272           0.9420        inf          0        nan         nan         nan
# x273           0.2952        inf          0        nan         nan         nan
# x274          -2.1792        inf         -0        nan         nan         nan
# x275          -3.0518        inf         -0        nan         nan         nan
# x276          -0.0936        inf         -0        nan         nan         nan
# x277           2.7784        inf          0        nan         nan         nan
# x278          -1.0444        inf         -0        nan         nan         nan
# x279          -1.2531        inf         -0        nan         nan         nan
# x280           2.3969        inf          0        nan         nan         nan
# x281          -3.2960        inf         -0        nan         nan         nan
# x282           0.1468        inf          0        nan         nan         nan
# x283           2.4519        inf          0        nan         nan         nan
# x284           0.5868        inf          0        nan         nan         nan
# x285           1.0838        inf          0        nan         nan         nan
# x286          -1.3336        inf         -0        nan         nan         nan
# x287           0.9920        inf          0        nan         nan         nan
# x288          -0.5657        inf         -0        nan         nan         nan
# x289           1.4747        inf          0        nan         nan         nan
# x290          -3.4967        inf         -0        nan         nan         nan
# x291          -2.3353        inf         -0        nan         nan         nan
# x292          -4.4931        inf         -0        nan         nan         nan
# x293          -1.2704        inf         -0        nan         nan         nan
# x294           0.2881        inf          0        nan         nan         nan
# x295          -4.4664        inf         -0        nan         nan         nan
# x296          -0.2252        inf         -0        nan         nan         nan
# x297           1.1017        inf          0        nan         nan         nan
# x298          -2.0439        inf         -0        nan         nan         nan
# x299           3.1647        inf          0        nan         nan         nan
# x300           0.4579        inf          0        nan         nan         nan
# ==============================================================================
# Omnibus:                        1.742   Durbin-Watson:                   1.781
# Prob(Omnibus):                  0.418   Jarque-Bera (JB):                1.813
# Skew:                          -0.200   Prob(JB):                        0.404
# Kurtosis:                       2.729   Cond. No.                         248.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The input rank is higher than the number of observations.
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: divide by zero encountered in divide
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1795: RuntimeWarning: invalid value encountered in scalar multiply
#   return 1 - (np.divide(self.nobs - self.k_constant, self.df_resid)
# /usr/local/lib/python3.11/dist-packages/statsmodels/regression/linear_model.py:1717: RuntimeWarning: divide by zero encountered in scalar divide
#   return np.dot(wresid, wresid) / self.df_resid

# %%
# Calculando o RMSE
pred = model.predict(X_test)

rms = root_mean_squared_error(y_test, pred)

print("RMSE com todas as variáveis:", rms)
# Out:
# RMSE com todas as variáveis: 0.804569667829403

# %% [markdown]
# ## Regressão Lasso

# %% [markdown]
# ### Dataset Completo

# %%
# Separando os dados
X = [np.array(embedding) for embedding in df_enem_aux['enunciado_embbedings_word2vec']]
y = df_enem_aux['nu_param_B']

# %%
# Aplicando Transformações
add_list = [(y.min() * (-1)) + 1] * len(y)
y = y + add_list

# Aplicando Boxcox
y, _ = stats.boxcox(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
model_lasso = LassoCV(alphas=[0.0001, 0.001, 0.01, 0.1, 1, 10], random_state=42).fit(
    X_train, y_train
)
pred_lasso = model_lasso.predict(X_test)

print("melhor r2 score (treino):", model_lasso.score(X_train, y_train))
print("r2 score (teste):", model_lasso.score(X_test, y_test))
print("melhor alpha:", model_lasso.alpha_)
print("RMSE com o alpha escolhido:", root_mean_squared_error(y_test, pred_lasso))
# Out:
# melhor r2 score (treino): 0.40448353255284286
# r2 score (teste): -0.15117102602594779
# melhor alpha: 0.001
# RMSE com o alpha escolhido: 0.5082764208689048

# %% [markdown]
# ### Modelo com corte na dificuldade (-3, 3)

# %%
enem_filtered = df_enem_aux.copy()
enem_filtered = enem_filtered[
    (enem_filtered["nu_param_B"] >= -3) & (enem_filtered["nu_param_B"] <= 3)
]
enem_filtered["nu_param_B"].describe()
# Out:
# count    263.000000
# mean       1.075595
# std        0.661348
# min       -0.726450
# 25%        0.612925
# 50%        1.051180
# 75%        1.535350
# max        2.802770
# Name: nu_param_B, dtype: float64

# %%
# Separando os dados
X = [np.array(embedding) for embedding in enem_filtered['enunciado_embbedings_word2vec']]
y = enem_filtered['nu_param_B']

# %%
# Aplicando Transformações
add_list = [(y.min() * (-1)) + 1] * len(y)
y = y + add_list

# Aplicando Boxcox
y, _ = stats.boxcox(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
model_lasso = LassoCV(alphas=[0.0001, 0.001, 0.01, 0.1, 1, 10, 100], random_state=42).fit(
    X_train, y_train
)
pred_lasso = model_lasso.predict(X_test)

print("melhor r2 score (treino):", model_lasso.score(X_train, y_train))
print("r2 score (teste):", model_lasso.score(X_test, y_test))
print("melhor alpha:", model_lasso.alpha_)
print("RMSE com o alpha escolhido:", root_mean_squared_error(y_test, pred_lasso))
# Out:
# melhor r2 score (treino): 0.43424444830997866
# r2 score (teste): 0.011537872316580211
# melhor alpha: 0.001
# RMSE com o alpha escolhido: 0.599207064043015
